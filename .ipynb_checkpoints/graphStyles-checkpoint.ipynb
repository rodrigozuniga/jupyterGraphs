# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
styles=['ggplot','fivethirtyeight','fast','grayscale']
# make data
x = np.linspace(0, 10, 100)
y = 4 + 2 * np.sin(2 * x)

fig,ax = plt.subplots(ncols=2,nrows=2,figsize=(20,20))

plt.suptitle('Subplots',color="blue",fontsize=40)

plt.subplot(2,2,1)
plt.style.use('ggplot')
plt.plot(x, y, linewidth=2.0)
plt.title('ggplot')

plt.subplot(2,2,2)
plt.style.use('fivethirtyeight')
plt.plot(x**15, 2*y, linewidth=2.0)
plt.title('fivethirtyeight')

plt.subplot(2,2,3)
plt.style.use('fast')
plt.plot(np.cos(x), 2*y, linewidth=2.0)
plt.title('fast')

plt.subplot(2,2,4)
plt.style.use('grayscale')
plt.plot(np.tan(x), 2*y, linewidth=2.0)
plt.title('grayscale')

plt.show()
# Out:
# [WinError 2] The system cannot find the file specified: "C:\\Users\\rodri\\Documents\\Programming\\Jupyter'"
# C:\Users\rodri
